# %%
import pandas as pd

# %% [markdown]
# # Retrieve COVID data from ECDC

# %%
covid_url = "https://opendata.ecdc.europa.eu/covid19/casedistribution/json/"
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import json
import urllib

# %%
covid_json_unformated = urllib.request.urlopen(covid_url).read().decode("utf-8")
covid_json = json.loads(covid_json_unformated)
cdf = pd.DataFrame(covid_json['records'])

# %%
cdf.shape
# Out:
# (61900, 12)

# %%
cdf.sample(10)
# Out:
#           dateRep day month  year  cases  deaths countriesAndTerritories  \
# 16019  15/09/2020  15    09  2020      1       0                Djibouti
# 28659  21/06/2020  21    06  2020      0       0             Isle_of_Man
# 27145  24/10/2020  24    10  2020   4369     118               Indonesia
# 56150  09/11/2020  09    11  2020     33       0                    Togo
# 36262  30/06/2020  30    06  2020      0       0                   Malta
# 5677   07/06/2020  07    06  2020     69      11                 Belgium
# 30376  14/11/2020  14    11  2020   4469      71                  Jordan
# 55884  07/11/2020  07    11  2020      0       0             Timor_Leste
# 11631  17/09/2020  17    09  2020      3       0                    Chad
# 24743  23/03/2020  23    03  2020      0       0                  Guinea
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 16019    DJ                  DJI     973557.0       Africa
# 28659    IM                  IMN      84589.0       Europe
# 27145    ID                  IDN  270625567.0         Asia
# 56150    TG                  TGO    8082359.0       Africa
# 36262    MT                  MLT     493559.0       Europe
# 5677     BE                  BEL   11455519.0       Europe
# 30376    JO                  JOR   10101697.0         Asia
# 55884    TL                  TLS    1293120.0         Asia
# 11631    TD                  TCD   15946882.0       Africa
# 24743    GN                  GIN   12771246.0       Africa
#
#       Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 16019                                          0.9244451
# 28659                                                  0
# 27145                                        21.15542912
# 56150                                         3.90974962
# 36262                                         2.83654031
# 5677                                         18.06116336
# 30376                                       665.71982905
# 55884                                         0.07733234
# 11631                                         0.45776974
# 24743

# %% [markdown]
# Rename columns to something more Pythonian. If you think they look already great, then at least rename `notification_rate_per_100000_population_14-days` to `14d-incidence`

# %%
cdf.rename(columns={"dateRep": "date", "countriesAndTerritories": "region", "geoId": "Geographical ID", "countryterritoryCode": "Region Code", "popData2019" : "population (2019)", "continentExp": "continent", "Cumulative_number_for_14_days_of_COVID-19_cases_per_100000": "14-day incidence"}, inplace = True)

cdf.head()
# Out:
#          date day month  year  cases  deaths       region Geographical ID  \
# 0  14/12/2020  14    12  2020    746       6  Afghanistan              AF
# 1  13/12/2020  13    12  2020    298       9  Afghanistan              AF
# 2  12/12/2020  12    12  2020    113      11  Afghanistan              AF
# 3  11/12/2020  11    12  2020     63      10  Afghanistan              AF
# 4  10/12/2020  10    12  2020    202      16  Afghanistan              AF
#
#   Region Code  population (2019) continent 14-day incidence
# 0         AFG         38041757.0      Asia       9.01377925
# 1         AFG         38041757.0      Asia       7.05277624
# 2         AFG         38041757.0      Asia       6.86876792
# 3         AFG         38041757.0      Asia       7.13426564
# 4         AFG         38041757.0      Asia       6.96865815

# %% [markdown]
# Identify which columns have not been casted to an appropriate type during loading!

# %%
cdf.dtypes
# Out:
# date                  object
# day                   object
# month                 object
# year                  object
# cases                  int64
# deaths                 int64
# region                object
# Geographical ID       object
# Region Code           object
# population (2019)    float64
# continent             object
# 14-day incidence      object
# dtype: object

# %% [markdown]
# We did not cover datetime objects in pandas, however they are quite powerful!
#
# Try:

# %%
cdf['date'] = pd.to_datetime(cdf['date'])

# %% [markdown]
# Now you can treat the column as a datetime objects using `df[col].dt` , e.g. https://docs.python.org/3/library/datetime.html#datetime.date.year

# %%
cdf['date'].dt.day.head()
# Out:
# 0    14
# 1    13
# 2    12
# 3    12
# 4    12
# Name: date, dtype: int64

# %%
cdf.head()
# Out:
#         date day month  year  cases  deaths       region Geographical ID  \
# 0 2020-12-14  14    12  2020    746       6  Afghanistan              AF
# 1 2020-12-13  13    12  2020    298       9  Afghanistan              AF
# 2 2020-12-12  12    12  2020    113      11  Afghanistan              AF
# 3 2020-11-12  11    12  2020     63      10  Afghanistan              AF
# 4 2020-10-12  10    12  2020    202      16  Afghanistan              AF
#
#   Region Code  population (2019) continent 14-day incidence
# 0         AFG         38041757.0      Asia       9.01377925
# 1         AFG         38041757.0      Asia       7.05277624
# 2         AFG         38041757.0      Asia       6.86876792
# 3         AFG         38041757.0      Asia       7.13426564
# 4         AFG         38041757.0      Asia       6.96865815

# %% [markdown]
# Create a new column `deltaTime_since_start_of_recording`

# %%
cdf.loc[0, 'date']
# Out:
# Timestamp('2020-12-14 00:00:00')

# %%
minimum = min(cdf['date'])

# %%
cdf.loc[0, 'date'] - min(cdf['date'])
# Out:
# Timedelta('349 days 00:00:00')

# %%
subset = cdf.head().copy()

# %%
cdf['deltaTime_since_start_of_recording'] = cdf['date'].apply(lambda x: x - minimum)

# %%
cdf
# Out:
#             date day month  year  cases  deaths       region Geographical ID  \
# 0     2020-12-14  14    12  2020    746       6  Afghanistan              AF
# 1     2020-12-13  13    12  2020    298       9  Afghanistan              AF
# 2     2020-12-12  12    12  2020    113      11  Afghanistan              AF
# 3     2020-11-12  11    12  2020     63      10  Afghanistan              AF
# 4     2020-10-12  10    12  2020    202      16  Afghanistan              AF
# ...          ...  ..   ...   ...    ...     ...          ...             ...
# 61895 2020-03-25  25    03  2020      0       0     Zimbabwe              ZW
# 61896 2020-03-24  24    03  2020      0       1     Zimbabwe              ZW
# 61897 2020-03-23  23    03  2020      0       0     Zimbabwe              ZW
# 61898 2020-03-22  22    03  2020      1       0     Zimbabwe              ZW
# 61899 2020-03-21  21    03  2020      1       0     Zimbabwe              ZW
#
#       Region Code  population (2019) continent 14-day incidence  \
# 0             AFG         38041757.0      Asia       9.01377925
# 1             AFG         38041757.0      Asia       7.05277624
# 2             AFG         38041757.0      Asia       6.86876792
# 3             AFG         38041757.0      Asia       7.13426564
# 4             AFG         38041757.0      Asia       6.96865815
# ...           ...                ...       ...              ...
# 61895         ZWE         14645473.0    Africa
# 61896         ZWE         14645473.0    Africa
# 61897         ZWE         14645473.0    Africa
# 61898         ZWE         14645473.0    Africa
# 61899         ZWE         14645473.0    Africa
#
#       deltaTime_since_start_of_recording
# 0                               349 days
# 1                               348 days
# 2                               347 days
# 3                               317 days
# 4                               286 days
# ...                                  ...
# 61895                            85 days
# 61896                            84 days
# 61897                            83 days
# 61898                            82 days
# 61899                            81 days
#
# [61900 rows x 13 columns]

# %% [markdown]
# Change 14-day incidence column from object to float.

# %%
cdf['14-day incidence'] = pd.to_numeric(cdf['14-day incidence'])

# %%
cdf.dtypes
# Out:
# date                                   datetime64[ns]
# day                                            object
# month                                          object
# year                                           object
# cases                                           int64
# deaths                                          int64
# region                                         object
# Geographical ID                                object
# Region Code                                    object
# population (2019)                             float64
# continent                                      object
# 14-day incidence                              float64
# deltaTime_since_start_of_recording    timedelta64[ns]
# dtype: object

# %% [markdown]
# Create histograms for different columns or describe the df. Can you spot the inconsistency in the data? Fix it! :)

# %%
import plotly.express as px

import numpy as np

# %%
# !pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in c:\users\miche\.vscode\advanced_python_2021-22_hd-1\.venv\lib\site-packages (0.2.1)

# %%
cdf.describe()
# Out:
#                cases        deaths  population (2019)  14-day incidence  \
# count   61900.000000  61900.000000       6.177700e+04      59021.000000
# mean     1155.147237     26.055460       4.098770e+07         66.320586
# std      6779.224479    131.227055       1.531294e+08        162.329240
# min     -8261.000000  -1918.000000       8.150000e+02       -147.419587
# 25%         0.000000      0.000000       1.293120e+06          0.757526
# 50%        15.000000      0.000000       7.169456e+06          6.724045
# 75%       273.000000      4.000000       2.851583e+07         52.572719
# max    234633.000000   4928.000000       1.433784e+09       1900.836210
#
#       deltaTime_since_start_of_recording
# count                              61900
# mean         188 days 16:08:43.890145394
# std           95 days 19:39:14.114916173
# min                      0 days 00:00:00
# 25%                    111 days 00:00:00
# 50%                    192 days 00:00:00
# 75%                    270 days 00:00:00
# max                    349 days 00:00:00

# %%
#remove negative values
cdf_cleaned = cdf[(cdf['cases']>=0) & (cdf['deaths'] >=0) & (cdf['14-day incidence']>=0)]

cdf_cleaned.describe()
# Out:
#                cases        deaths  population (2019)  14-day incidence  \
# count   58959.000000  58959.000000       5.895900e+04      58959.000000
# mean     1212.754168     27.316135       4.124131e+07         66.402666
# std      6941.109276    133.162595       1.537655e+08        162.373044
# min         0.000000      0.000000       8.150000e+02          0.000000
# 25%         0.000000      0.000000       1.324820e+06          0.763241
# 50%        20.000000      0.000000       7.813207e+06          6.732521
# 75%       310.000000      5.000000       2.860872e+07         52.601692
# max    234633.000000   4928.000000       1.433784e+09       1900.836210
#
#       deltaTime_since_start_of_recording
# count                              58959
# mean         191 days 20:55:00.870096166
# std           94 days 23:25:18.727953598
# min                      2 days 00:00:00
# 25%                    117 days 00:00:00
# 50%                    196 days 00:00:00
# 75%                    272 days 00:00:00
# max                    349 days 00:00:00

# %%
def create_plots(df, directory):
    for col in df.columns:
        if df[col].dtypes not in [np.int64,np.float64]:
            continue
        else:
            fig = px.histogram(df, x=col)
            fig.write_image(f"{directory}/"+col+".png")

# %%
create_plots(cdf_cleaned, 'histograms')

# %% [markdown]
# Identify those countries (grouped by continent) which showed the most drastic increase most drastic and decrease of the `14d-incidence` within the different years since recording. Visualize intuitively!

# %%
def calculate_in_decrease(df, col_meta = 'region', col_1 = 'date', col_2 = '14-day incidence'):

    set_of_meta_values = set(df[col_meta])

    dict = {}

    for meta_value in set_of_meta_values:

        subset = df[df[col_meta] == meta_value]

        maximum_date = max(subset[col_1])

        minimum_date = min(subset[col_1])
        
        incidence_2 = subset[subset[col_1] == maximum_date][col_2]  

        incidence_2 = incidence_2.values[0]

        incidence_1 = subset[subset[col_1] == minimum_date][col_2] 

        incidence_1 = incidence_1.values[0]

        dif = incidence_2 - incidence_1

        dict.update({meta_value: dif})

    return dict

# %%
dict_region = calculate_in_decrease(cdf_cleaned)

# %%
df_region = pd.DataFrame.from_dict(dict_region, orient='index')

df_region.rename(columns = {0: "14-day incidence change within year"}, inplace=True)

df_region
# Out:
#                                   14-day incidence change within year
# India                                                       33.109055
# Ireland                                                     80.420208
# Turks_and_Caicos_islands                                    52.364246
# Togo                                                         3.167392
# Laos                                                         0.027896
# ...                                                               ...
# South_Sudan                                                  0.596631
# Yemen                                                        0.003429
# Trinidad_and_Tobago                                          9.964379
# Democratic_Republic_of_the_Congo                             1.977173
# Uganda                                                      16.623150
#
# [212 rows x 1 columns]

# %%
list_continent = []

for region in df_region.index.values.tolist():
    continent = cdf[cdf['region'] == region]['continent'].values[0]

    list_continent.append(continent)

df_region['continent'] = list_continent

df_region
# Out:
#                                   14-day incidence change within year  \
# India                                                       33.109055
# Ireland                                                     80.420208
# Turks_and_Caicos_islands                                    52.364246
# Togo                                                         3.167392
# Laos                                                         0.027896
# ...                                                               ...
# South_Sudan                                                  0.596631
# Yemen                                                        0.003429
# Trinidad_and_Tobago                                          9.964379
# Democratic_Republic_of_the_Congo                             1.977173
# Uganda                                                      16.623150
#
#                                  continent
# India                                 Asia
# Ireland                             Europe
# Turks_and_Caicos_islands           America
# Togo                                Africa
# Laos                                  Asia
# ...                                    ...
# South_Sudan                         Africa
# Yemen                                 Asia
# Trinidad_and_Tobago                America
# Democratic_Republic_of_the_Congo    Africa
# Uganda                              Africa
#
# [212 rows x 2 columns]

# %%
df_region['region'] = df_region.index

# %%
grps = df_region.groupby(['continent'])

increase = grps.max()

increase
# Out:
#            14-day incidence change within year          region
# continent
# Africa                              139.107096        Zimbabwe
# America                             909.950276       Venezuela
# Asia                                557.933056           Yemen
# Europe                             1388.098666  United_Kingdom
# Oceania                             531.714915         Vanuatu

# %%
lat = [-22.21667, 4.60226, 12.64881, 50.10319, -19.55]

lng = [25.83066, -72.55212, 42.95452, -7.64133, 167.16235]

increase['lat'] = lat

increase['lng'] = lng

increase
# Out:
#            14-day incidence change within year          region       lat  \
# continent
# Africa                              139.107096        Zimbabwe -22.21667
# America                             909.950276       Venezuela   4.60226
# Asia                                557.933056           Yemen  12.64881
# Europe                             1388.098666  United_Kingdom  50.10319
# Oceania                             531.714915         Vanuatu -19.55000
#
#                  lng
# continent
# Africa      25.83066
# America    -72.55212
# Asia        42.95452
# Europe      -7.64133
# Oceania    167.16235

# %%
fig = px.scatter_mapbox(
    increase, 
    lat='lat', 
    lon='lng', 
    hover_name='14-day incidence change within year',
    zoom=1,
    size='14-day incidence change within year',
    mapbox_style="stamen-terrain"
)
fig.show()

# %%
decrease = grps.min()

decrease
# Out:
#            14-day incidence change within year       region
# continent
# Africa                               -9.166862      Algeria
# America                              -5.574505     Anguilla
# Asia                                -18.603108  Afghanistan
# Europe                             -613.496933      Albania
# Oceania                              -5.102822    Australia

# %%
lat = [36.737232,18.227230,34.543896,41.327953,-33.865143]
lng = [3.086472,-63.048988,69.160652,19.819025,151.209900]

decrease['lat'] = lat

decrease['lng'] = lng

decrease
# Out:
#            14-day incidence change within year       region        lat  \
# continent
# Africa                               -9.166862      Algeria  36.737232
# America                              -5.574505     Anguilla  18.227230
# Asia                                -18.603108  Afghanistan  34.543896
# Europe                             -613.496933      Albania  41.327953
# Oceania                              -5.102822    Australia -33.865143
#
#                   lng
# continent
# Africa       3.086472
# America    -63.048988
# Asia        69.160652
# Europe      19.819025
# Oceania    151.209900

# %%
fig = px.scatter_mapbox(
    decrease, 
    lat='lat', 
    lon='lng', 
    hover_name='14-day incidence change within year',
    zoom=1,
    size= decrease["14-day incidence change within year"].abs(),
    size_max=50,
    color_discrete_sequence=["red"],
    mapbox_style="stamen-terrain"
)
fig.show()

# %% [markdown]
# Which country showed the highest/lowest fluctuation in `14d-incidence` within a year?

# %%
def calculate_fluctuation(df, col_meta = 'region', col = '14-day incidence'):

    set_of_meta_values = set(df[col_meta])

    dict = {}

    for meta_value in set_of_meta_values:

        subset = df[df[col_meta] == meta_value]

        sd = np.std(subset[col])

        dict.update({meta_value: sd})

    return dict

# %%
dict_fluct = calculate_fluctuation(cdf_cleaned)

print(f'The country with the highest fluctutation is {max(dict_fluct)}.')
print(f'The country with the lowest fluctutation is {min(dict_fluct)}.')
# Out:
# The country with the highest fluctutation is Zimbabwe.
# The country with the lowest fluctutation is Afghanistan.

# %% [markdown]
# Create a line plot showing the `14-incidence` for all European countries. Use `groupby` operation to generate the data list for the plotly plot.

# %%
subset_europe = cdf_cleaned[cdf_cleaned['continent'] == 'Europe']

fig = px.line(subset_europe, x="date", y="14-day incidence", color='region')
fig.show()

# %% [markdown]
# Create a smoothed version of the `14d-incidence` by averaging 3 months.

# %%
from collections import deque

# %%
def sliding_window(y_data, window_size):

    sliding_window = deque([], maxlen = window_size)
    mean_list = []
    for y in y_data:
        sliding_window.append(y)
        mean = np.mean(list(sliding_window))
        mean_list.append(mean)
    return mean_list

# %%
mean_list = sliding_window(cdf_cleaned['14-day incidence'], 90)

cdf_averaged = cdf_cleaned.copy()

cdf_averaged['14-day incidence'] = mean_list

cdf_averaged
# Out:
#             date day month  year  cases  deaths       region Geographical ID  \
# 0     2020-12-14  14    12  2020    746       6  Afghanistan              AF
# 1     2020-12-13  13    12  2020    298       9  Afghanistan              AF
# 2     2020-12-12  12    12  2020    113      11  Afghanistan              AF
# 3     2020-11-12  11    12  2020     63      10  Afghanistan              AF
# 4     2020-10-12  10    12  2020    202      16  Afghanistan              AF
# ...          ...  ..   ...   ...    ...     ...          ...             ...
# 61882 2020-07-04  07    04  2020      0       0     Zimbabwe              ZW
# 61883 2020-06-04  06    04  2020      0       0     Zimbabwe              ZW
# 61884 2020-05-04  05    04  2020      0       0     Zimbabwe              ZW
# 61885 2020-04-04  04    04  2020      1       0     Zimbabwe              ZW
# 61886 2020-03-04  03    04  2020      0       0     Zimbabwe              ZW
#
#       Region Code  population (2019) continent  14-day incidence  \
# 0             AFG         38041757.0      Asia          9.013779
# 1             AFG         38041757.0      Asia          8.033278
# 2             AFG         38041757.0      Asia          7.645108
# 3             AFG         38041757.0      Asia          7.517397
# 4             AFG         38041757.0      Asia          7.407649
# ...           ...                ...       ...               ...
# 61882         ZWE         14645473.0    Africa          0.601248
# 61883         ZWE         14645473.0    Africa          0.585695
# 61884         ZWE         14645473.0    Africa          0.575149
# 61885         ZWE         14645473.0    Africa          0.564073
# 61886         ZWE         14645473.0    Africa          0.549203
#
#       deltaTime_since_start_of_recording
# 0                               349 days
# 1                               348 days
# 2                               347 days
# 3                               317 days
# 4                               286 days
# ...                                  ...
# 61882                           186 days
# 61883                           156 days
# 61884                           125 days
# 61885                            95 days
# 61886                            64 days
#
# [58959 rows x 13 columns]

# %%
subset_europe = cdf_averaged[cdf_averaged['continent'] == 'Europe']

fig = px.line(subset_europe, x="date", y="14-day incidence", color='region')
fig.show()

# %% [markdown]
# Create a radial plot of death rate / 100000 people (see popData2019), where one year completes a circle, i.e. 360˚. Visualize the recored years for Italy, Germany, Sweden and Greece. Hint you might need to turn the dateTime into `day within the year` (%j) and adjust 365 to 360 degrees.

# %%
cdf_cleaned['death rate'] = cdf_cleaned.apply(lambda x: x['deaths']/x['population (2019)']*100000, axis=1)

cdf_cleaned
# Out:
# C:\Users\miche\AppData\Local\Temp/ipykernel_21356/1164539909.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             date day month  year  cases  deaths       region Geographical ID  \
# 0     2020-12-14  14    12  2020    746       6  Afghanistan              AF
# 1     2020-12-13  13    12  2020    298       9  Afghanistan              AF
# 2     2020-12-12  12    12  2020    113      11  Afghanistan              AF
# 3     2020-11-12  11    12  2020     63      10  Afghanistan              AF
# 4     2020-10-12  10    12  2020    202      16  Afghanistan              AF
# ...          ...  ..   ...   ...    ...     ...          ...             ...
# 61882 2020-07-04  07    04  2020      0       0     Zimbabwe              ZW
# 61883 2020-06-04  06    04  2020      0       0     Zimbabwe              ZW
# 61884 2020-05-04  05    04  2020      0       0     Zimbabwe              ZW
# 61885 2020-04-04  04    04  2020      1       0     Zimbabwe              ZW
# 61886 2020-03-04  03    04  2020      0       0     Zimbabwe              ZW
#
#       Region Code  population (2019) continent  14-day incidence  \
# 0             AFG         38041757.0      Asia          9.013779
# 1             AFG         38041757.0      Asia          7.052776
# 2             AFG         38041757.0      Asia          6.868768
# 3             AFG         38041757.0      Asia          7.134266
# 4             AFG         38041757.0      Asia          6.968658
# ...           ...                ...       ...               ...
# 61882         ZWE         14645473.0    Africa          0.047796
# 61883         ZWE         14645473.0    Africa          0.047796
# 61884         ZWE         14645473.0    Africa          0.047796
# 61885         ZWE         14645473.0    Africa          0.054624
# 61886         ZWE         14645473.0    Africa          0.054624
#
#       deltaTime_since_start_of_recording  death rate
# 0                               349 days    0.015772
# 1                               348 days    0.023658
# 2                               347 days    0.028916
# 3                               317 days    0.026287
# 4                               286 days    0.042059
# ...                                  ...         ...
# 61882                           186 days    0.000000
# 61883                           156 days    0.000000
# 61884                           125 days    0.000000
# 61885                            95 days    0.000000
# 61886                            64 days    0.000000
#
# [58959 rows x 14 columns]

# %%
import plotly.graph_objects as go

# %%
subset_radial_plot = cdf_cleaned[(cdf_cleaned['region'] == 'Germany') | (cdf_cleaned['region'] == 'Italy') | (cdf_cleaned['region'] == 'Sweden') | (cdf_cleaned['region'] == 'Greece')]

subset_radial_plot
# Out:
#             date day month  year  cases  deaths   region Geographical ID  \
# 21880 2020-12-14  14    12  2020  16362     188  Germany              DE
# 21881 2020-12-13  13    12  2020  20200     321  Germany              DE
# 21882 2020-12-12  12    12  2020  28438     496  Germany              DE
# 21883 2020-11-12  11    12  2020  29875     598  Germany              DE
# 21884 2020-10-12  10    12  2020  23679     440  Germany              DE
# ...          ...  ..   ...   ...    ...     ...      ...             ...
# 54291 2020-01-17  17    01  2020      0       0   Sweden              SE
# 54292 2020-01-16  16    01  2020      0       0   Sweden              SE
# 54293 2020-01-15  15    01  2020      0       0   Sweden              SE
# 54294 2020-01-14  14    01  2020      0       0   Sweden              SE
# 54295 2020-01-13  13    01  2020      0       0   Sweden              SE
#
#       Region Code  population (2019) continent  14-day incidence  \
# 21880         DEU         83019213.0    Europe        341.136696
# 21881         DEU         83019213.0    Europe        334.881517
# 21882         DEU         83019213.0    Europe        328.149341
# 21883         DEU         83019213.0    Europe        320.027124
# 21884         DEU         83019213.0    Europe        311.512228
# ...           ...                ...       ...               ...
# 54291         SWE         10230185.0    Europe          0.000000
# 54292         SWE         10230185.0    Europe          0.000000
# 54293         SWE         10230185.0    Europe          0.000000
# 54294         SWE         10230185.0    Europe          0.000000
# 54295         SWE         10230185.0    Europe          0.000000
#
#       deltaTime_since_start_of_recording  death rate
# 21880                           349 days    0.226454
# 21881                           348 days    0.386657
# 21882                           347 days    0.597452
# 21883                           317 days    0.720315
# 21884                           286 days    0.529998
# ...                                  ...         ...
# 54291                            17 days    0.000000
# 54292                            16 days    0.000000
# 54293                            15 days    0.000000
# 54294                            14 days    0.000000
# 54295                            13 days    0.000000
#
# [1344 rows x 14 columns]

# %%
subset_radial_plot['theta'] = subset_radial_plot['deltaTime_since_start_of_recording']/360
# Out:
# C:\Users\miche\AppData\Local\Temp/ipykernel_21356/3345766837.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
px.line_polar(subset_radial_plot, r='death rate', theta='theta', color='region')

# %% [markdown]
# # Illuminaty confirmed.
